# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
data=pd.read_csv(r'D:\ICTAK\Assignment 3\StudentsPerformance.csv')
data
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group C            some high school  free/reduced
# 1    female        group B                 high school  free/reduced
# 2    female        group B            some high school  free/reduced
# 3    female        group B                some college      standard
# 4    female        group C                some college  free/reduced
# ..      ...            ...                         ...           ...
# 995    male        group E                some college      standard
# 996    male        group A                some college      standard
# 997    male        group D                some college      standard
# 998    male        group E          associate's degree  free/reduced
# 999    male        group E           bachelor's degree      standard
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   gender                       1000 non-null   object
#  1   race/ethnicity               1000 non-null   object
#  2   parental level of education  1000 non-null   object
#  3   lunch                        1000 non-null   object
#  4   test preparation course      1000 non-null   object
#  5   math score                   1000 non-null   int64
#  6   reading score                1000 non-null   int64
#  7   writing score                1000 non-null   int64
# dtypes: int64(3), object(5)
# memory usage: 62.6+ KB

# %% [markdown]
# # Question 1

# %%
data['gender'].value_counts()
# Out:
# female    518
# male      482
# Name: gender, dtype: int64

# %%
data['parental level of education'].value_counts()
# Out:
# some college          226
# associate's degree    222
# high school           196
# some high school      179
# bachelor's degree     118
# master's degree        59
# Name: parental level of education, dtype: int64

# %%
data['Average_marks']=data['math score']+data['reading score']+data['writing score']/3
data
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group C            some high school  free/reduced
# 1    female        group B                 high school  free/reduced
# 2    female        group B            some high school  free/reduced
# 3    female        group B                some college      standard
# 4    female        group C                some college  free/reduced
# ..      ...            ...                         ...           ...
# 995    male        group E                some college      standard
# 996    male        group A                some college      standard
# 997    male        group D                some college      standard
# 998    male        group E          associate's degree  free/reduced
# 999    male        group E           bachelor's degree      standard
#
#     test preparation course  math score  reading score  writing score  \
# ...

# %% [markdown]
# # Question 2

# %%
sns.countplot(x=data['parental level of education'])
plt.xticks(rotation=90)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.bar(data['parental level of education'],data['Average_marks'])
plt.xlabel('parental level of education')
plt.ylabel('Average_marks')
plt.xticks(rotation=90)
plt.show()

# %%
#There is no impact on parental level of education and their children's average marks.

# %% [markdown]
# # Question 3

# %%
plt.bar(data['gender'],data['Average_marks'])
plt.xlabel('gender')
plt.ylabel('Average_marks')
plt.xticks(rotation=90)
plt.show()

# %%
plt.bar(data['test preparation course'],data['Average_marks'])
plt.xlabel('test preparation course')
plt.ylabel('Average_marks')
plt.xticks(rotation=90)
plt.show()

# %%
#both based on gender and test preparation course, both (male or female and none or completed) scored same level of average marks.

# %% [markdown]
# # Question 4

# %%
plt.bar(data['gender'],data['math score'])
plt.xlabel('gender')
plt.ylabel('math score')
plt.xticks(rotation=90)
plt.show()

# %%
plt.bar(data['gender'],data['reading score'])
plt.xlabel('gender')
plt.ylabel('reading score')
plt.xticks(rotation=90)
plt.show()

# %%
plt.bar(data['gender'],data['writing score'])
plt.xlabel('gender')
plt.ylabel('writing score')
plt.xticks(rotation=90)
plt.show()

# %%
plt.bar(data['test preparation course'],data['writing score'])
plt.xlabel('test preparation course')
plt.ylabel('writing score')
plt.xticks(rotation=90)
plt.show()

# %%
plt.bar(data['test preparation course'],data['reading score'])
plt.xlabel('test preparation course')
plt.ylabel('reading score')
plt.xticks(rotation=90)
plt.show()

# %%
plt.bar(data['test preparation course'],data['math score'])
plt.xlabel('test preparation course')
plt.ylabel('math score')
plt.xticks(rotation=90)
plt.show()

# %%
#there is no variation in math, reading and writing scores based on gender and test preparation course.

# %% [markdown]
# # Question 5

# %%
data.nlargest(250,['math score'])
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 515  female        group E                some college      standard
# 516  female        group E           bachelor's degree      standard
# 517  female        group E          associate's degree      standard
# 996    male        group A                some college      standard
# 997    male        group D                some college      standard
# ..      ...            ...                         ...           ...
# 428  female        group D                some college  free/reduced
# 429  female        group E            some high school      standard
# 849    male        group A           bachelor's degree      standard
# 850    male        group C          associate's degree  free/reduced
# 851    male        group D                some college      standard
#
#     test preparation course  math score  reading score  writing score  \
# ...
